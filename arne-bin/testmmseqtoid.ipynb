# %%
import re
import os
import glob
import pickle
import string
import base64
import hashlib
import argparse
from sys import argv
from pathlib import Path
from functools import partial
from multiprocessing import Pool, TimeoutError
from Bio import AlignIO
import pandas as pd

# %%
def get_accession2id(db_path, taxid=True):
    if taxid:
        pkl_path = f"{db_path}/seqid2taxid.pkl"
    else:
        pkl_path = f"{db_path}/seqid2repid.pkl"

    if not os.path.exists(pkl_path):
        print("Generating accession to taxid dictionary")
        make_accession2id(db_path)
    
    print("Loading accession to taxid dictionary")
    with open(pkl_path, "rb") as input_file:
        return pickle.load(input_file)

# %%
def make_accession2id(db_path):
    print("Generating accession2taxid pickle file")
    seqid_to_taxid_dic = {}
    seqid_to_repid_dic = {}
    header_files = glob.glob(f"{db_path}/*_h.tsv")
    ptax = re.compile("TaxID=([0-9]+)")
    prep = re.compile("RepID=[A-Z0-9]+[_]([A-Z0-9]+)")
    
    for header_file in header_files:
        print(f"Looking for taxids in {header_file}")
        with open(header_file) as headers:
            for header in headers:
                match_taxid = ptax.search(header)
                match_repid = prep.search(header)
                accession = header.split()[1]
                if match_taxid:
                    taxid = match_taxid.group(1)
                    seqid_to_taxid_dic[accession] = int(taxid)
                if match_repid:
                    repid = match_repid.group(1)
                    seqid_to_repid_dic[accession] = repid
    
    with open(seqid_to_taxid, 'wb') as f:
      pickle.dump(seqid_to_taxid_dic, f, protocol=4)
    with open(seqid_to_repid, 'wb') as f:
      pickle.dump(seqid_to_repid_dic, f, protocol=4)

# %%
def convert_alignment(in_alignment, out_dir, taxid,duplicate=False):
    seqids = set()
    tolower = str.maketrans('', '', string.ascii_lowercase)
    print(f"Opening {in_alignment}")
    with open(in_alignment) as aln:
        a3m_data = iter(aln.readlines())
    print(f"{in_alignment} loaded")
    # always write first (target) sequence to file
    target_header = next(a3m_data)
    target_seq = next(a3m_data)
    
    # prepare the directory structure as AF wants it
    target_id = target_header.strip().strip(">")
    print(f"Target ID: {target_id}")
    Path(out_dir, target_id, "msas", "A").mkdir(parents=True, exist_ok=True)
    pseudo_uniprot = open(f"{out_dir}/{target_id}/msas/A/uniprot_hits.a3m", "w")
    pseudo_uniprot.write(target_header)
    pseudo_uniprot.write(target_seq)
    print(f"Starting conversion: {target_id}")
    #duplicateentries=False
    memid=None
    if (duplicate):     
        for line in a3m_data:
            if line.startswith(">"):
                if memid:
                    for i in range(len(memid)):
                        pseudo_uniprot.write(uniprotid[i])
                        pseudo_uniprot.write(sequence)   
                memid = []
                seqid = line.split()[0].strip(">") # gets accession ID
                tempid=[]
                #print ("Testing1 seqid",seqid,len(seqid_to_id))
                longseqid="UniRef100_"+seqid
                shortseqid=re.sub("UniRef100_", "", seqid)
                if  (longseqid not in seqids) and  (shortseqid not in seqids) and (seqid not in seqids): # avoids duplicates
                    #print ("Adding seqid",seqid)
                    seqids.add(seqid)
                    seqids.add(longseqid)
                    seqids.add(shortseqid)
                else:
                    continue
                #print ("Testing2 seqid",seqid)                  
                #print ("test",seqid,seqid_to_id[seqid])                    
                if seqid in seqid_to_id:
                    try:
                        memid = seqid_to_id[seqid].split(",")
                        print ("test1")
                    except:
                        memid.append(str(seqid_to_id[seqid]))
                        print ("test2")
                    #memid = seqid_to_id[seqid]
                    tempid=memid.copy()
                    #print ("updating seqid1",seqid,memid)
                elif longseqid in seqid_to_id:
                    try:
                        memid = seqid_to_id[longseqid].split(",")
                    except:
                        memid.append(str(seqid_to_id[longseqid]))
                    tempid=memid.copy()
                    #print ("updating seqid2",longseqid,memid)
                elif shortseqid in seqid_to_id: 
                    try:
                        memid = seqid_to_id[shortseqid].split(",")
                    except:
                        memid.append(str(seqid_to_id[shortseqid]))
                    tempid=memid.copy()
                    #print ("updating seqid3",shortseqid,memid)
                #else:
                #    print ("no match:",seqid,memid,len(seqid_to_id))
                if taxid:
                    if (memid):
                        j=0
                        for i in memid:
                            memid[j] = base64.urlsafe_b64encode(hashlib.md5(str(i).encode('utf-8')).digest()).decode("utf-8").replace("_", "").replace("-", "")[:5].upper()                   
                            j+=1
                    else:
                        memid=["NOSPECIEFOUND"]
                        tempid=["NOSPECIEFOUND"]      
                if memid:
                    uniprotid=[]
                    print ("updating outputs",memid)
                    for i in range(len(memid)):
                        print ("memid",i,memid[i],tempid[i])
                        m=memid[i]
                        t=tempid[i]   
                        seqid_alpha=re.sub(r"[^a-zA-Z0-9]", '', seqid)+str(i)
                        #pseudo_uniprot.write(f">tr|{seqid_alpha}|{seqid_alpha}_{memid}/1-{len(target_seq)} Seq:{seqid} Temp:{tempid} mem:{memid}\n")
                        #pseudo_uniprot.write(f">tr|{seqid_alpha}|{seqid_alpha}_{memid}/1-{len(target_seq)} Memid:{tempid}\n")
                        uniprotid.append(f">tr|{seqid_alpha}|{seqid_alpha}_{m}/1-{len(target_seq)} Memid:{t}\n")
                        print ("uniprotid:",i,uniprotid)
                sequence=''
            elif memid:
                #pseudo_uniprot.write(line.translate(tolower)))
                sequence+=line.translate(tolower)
        if memid:
            for i in range(len(memid)):
                pseudo_uniprot.write(uniprotid[i])
                pseudo_uniprot.write(sequence)    
    else:
        for line in a3m_data:
            if line.startswith(">"):
                memid = None
                seqid = line.split()[0].strip(">") # gets accession ID
                tempid=""
                #print ("Testing1 seqid",seqid,len(seqid_to_id))
                longseqid="UniRef100_"+seqid
                shortseqid=re.sub("UniRef100_", "", seqid)
                if  (longseqid not in seqids) and  (shortseqid not in seqids) and (seqid not in seqids): # avoids duplicates
                    #print ("Adding seqid",seqid)
                    seqids.add(seqid)
                    seqids.add(longseqid)
                    seqids.add(shortseqid)
                else:
                    continue
                #print ("Testing2 seqid",seqid)                  
                if seqid in seqid_to_id:
                    memid = seqid_to_id[seqid]
                    tempid=memid
                    #print ("updating seqid1",seqid,memid)
                elif longseqid in seqid_to_id:
                    memid = seqid_to_id[longseqid]
                    tempid=memid
                    #print ("updating seqid2",seqid,memid)
                elif shortseqid in seqid_to_id: 
                    memid = seqid_to_id[shortseqid]
                    tempid=memid
                    #print ("updating seqid3",seqid,memid)
                #else:
                #    print ("no match:",seqid,memid,len(seqid_to_id))
                if taxid:
                    if (memid):
                        memid = base64.urlsafe_b64encode(hashlib.md5(str(memid).encode('utf-8')).digest()).decode("utf-8").replace("_", "").replace("-", "")[:5].upper()
                    else:
                        memid="NOSPECIEFOUND"      
                if memid:
                    seqid_alpha = re.sub(r"[^a-zA-Z0-9]", '', seqid)
                    #pseudo_uniprot.write(f">tr|{seqid_alpha}|{seqid_alpha}_{memid}/1-{len(target_seq)} Seq:{seqid} Temp:{tempid} mem:{memid}\n")
                    pseudo_uniprot.write(f">tr|{seqid_alpha}|{seqid_alpha}_{memid}/1-{len(target_seq)} Memid:{tempid}\n")
      
            elif memid:
                pseudo_uniprot.write(line.translate(tolower))



                
    pseudo_uniprot.close()

    input_handle  = open(f"{out_dir}/{target_id}/msas/A/uniprot_hits.a3m", "r")
    output_handle = open(f"{out_dir}/{target_id}/msas/A/uniprot_hits.sto", "w")

    alignments = AlignIO.parse(input_handle, "fasta")
    AlignIO.write(alignments, output_handle, "stockholm")

    output_handle.close()
    input_handle.close()
    
    # bfd symlink
    src = os.path.abspath(in_alignment)
    dst = f"{os.path.abspath(out_dir)}/{target_id}/msas/A/bfd_uniref_hits.a3m"

    if os.path.exists(dst):
        os.remove(dst)
    os.symlink(src, dst)

# %%
def main(args):
    #print ("ARGS",args)
    taxid = False if args.repid else True
    #seqid_to_id = get_accession2id(args.db_path, taxid=taxid)
    print ("SEQID:",taxid,len(seqid_to_id))
    a3ms = glob.glob(f"{args.in_path}/*.a3m")
    #print(f"Converting alignments: {a3ms}")
    with Pool(processes=int(args.n_cpu)) as pool:
        pool.map(partial(convert_alignment, out_dir=args.out_dir, taxid=taxid, 
                         duplicate=args.duplicate), a3ms)
    #for aln in a3ms:
    #    print(f"Converting alignments: {aln}")
    #    convert_alignment(aln,args.out_dir,seqid_to_id,taxid)

# %%
if __name__ == '__main__':
    parser = argparse.ArgumentParser(description="Converts an a3m alignment (e.g. MMseqs2 alignment) to a Stockholm alignment \
                                 that can be used for MSA pairing in AlphaFold-multimer runs")
    parser.add_argument("in_path", help = "Path to the a3m alignment file directory")
    parser.add_argument("out_dir", help = "Path to output directory")
    parser.add_argument("db_path", help = "Path to ColabFold databases")
    parser.add_argument("--n_cpu", default=8, type=int)
    parser.add_argument("--taxid", action="store_true", default=True, help = "If tax IDs should be used in the pairing procedure")
    parser.add_argument("--repid", action="store_true", default=False, help = "If mnemonic species IDs should be used in the pairing procedure")
    parser.add_argument("--duplicate", action="store_true", default=False, help = "If we should add duplicate species to the uniprot file")
    args = parser.parse_args()
    taxid = False if args.repid else True    
    seqid_to_id = get_accession2id(args.db_path, taxid=taxid)
    #print ("tt",len(seqid_to_id))
    main(args)
# Out:
# usage: ipykernel_launcher.py [-h] [--n_cpu N_CPU] [--taxid] [--repid]
#                              [--duplicate]
#                              in_path out_dir db_path
# ipykernel_launcher.py: error: the following arguments are required: in_path, out_dir, db_path
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /software/sse/easybuild/prefix/software/Anaconda3/2021.05-nsc1/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
taxid=True
seqid_to_id = get_accession2id("/proj/berzelius-2021-29/users/x_arnel/herpes/family_duplicate/", taxid=taxid)
# Out:
# Loading accession to taxid dictionary

# %%
in_path="/proj/berzelius-2021-29/users/x_arnel/herpes/msa_test/"
out_dir="/proj/berzelius-2021-29/users/x_arnel/herpes/multimer_test/"
duplicate=True
a3ms = glob.glob(f"{in_path}/*.a3m")

# %%
for aln in a3ms:
    print(f"Converting alignments: {aln}")
    convert_alignment(aln,out_dir,seqid_to_id,taxid)
# Out:
# Converting alignments: /proj/berzelius-2021-29/users/x_arnel/herpes/msa_test/134.a3m
# Opening /proj/berzelius-2021-29/users/x_arnel/herpes/msa_test/134.a3m
# /proj/berzelius-2021-29/users/x_arnel/herpes/msa_test/134.a3m loaded
# Target ID: P57053
# Starting conversion: P57053
# test2
# updating outputs ['2FU6H']
# memid 0 2FU6H 32523
# uniprotid: 0 ['>tr|UniRef100A0A1B8Y8540|UniRef100A0A1B8Y8540_2FU6H/1-127 Memid:32523\n']
# test2
# updating outputs ['1KKO7']
# memid 0 1KKO7 9157
# uniprotid: 0 ['>tr|UniRef100UPI000771520D0|UniRef100UPI000771520D0_1KKO7/1-127 Memid:9157\n']
# test2
# updating outputs ['BNJAO']
# memid 0 BNJAO 59463
# uniprotid: 0 ['>tr|UniRef100G1Q2Z10|UniRef100G1Q2Z10_BNJAO/1-127 Memid:59463\n']
# test2
# updating outputs ['ZWFTZ']
# memid 0 ZWFTZ 2593467
# uniprotid: 0 ['>tr|UniRef100A0A8C5TVD80|UniRef100A0A8C5TVD80_ZWFTZ/1-127 Memid:2593467\n']
# test2
# updating outputs ['CE6RH']
# memid 0 CE6RH 9347
# uniprotid: 0 ['>tr|UniRef100S9YQL70|UniRef100S9YQL70_CE6RH/1-127 Memid:9347\n']
# test2
# updating outputs ['0D1UT']
# memid 0 0D1UT 260995
# uniprotid: 0 ['>tr|UniRef100A0A6P8S0760|UniRef100A0A6P8S0760_0D1UT/1-127 Memid:260995\n']
# test2
# updating outputs ['2ZAD6']
# memid 0 2ZAD6 445787
# uniprotid: 0 ['>tr|UniRef100A0A8C5MT470|UniRef100A0A8C5MT470_2ZAD6/1-127 Memid:445787\n']
# test2
# updating outputs ['4BETU']
# memid 0 4BETU 2715852
# uniprotid: 0 ['>tr|UniRef100A0A2K5PC890|UniRef100A0A2K5PC890_4BETU/1-127 Memid:2715852\n']
# test2
# updating outputs ['RXVCR']
# memid 0 RXVCR 7906
# uniprotid: 0 ['>tr|UniRef100UPI00145BB4A80|UniRef100UPI00145BB4A80_RXVCR/1-127 Memid:7906\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8IZ650|UniRef100L8IZ650_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100UPI0001D5736A0|UniRef100UPI0001D5736A0_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['R6OJP']
# memid 0 R6OJP 9470
# uniprotid: 0 ['>tr|UniRef100UPI00234C45780|UniRef100UPI00234C45780_R6OJP/1-127 Memid:9470\n']
# test2
# updating outputs ['0ETJH']
# memid 0 0ETJH 9515
# uniprotid: 0 ['>tr|UniRef100A0A6J3GPF20|UniRef100A0A6J3GPF20_0ETJH/1-127 Memid:9515\n']
# test2
# updating outputs ['H5CC2']
# memid 0 H5CC2 8663
# uniprotid: 0 ['>tr|UniRef100A0A6J1VAS10|UniRef100A0A6J1VAS10_H5CC2/1-127 Memid:8663\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3G6R30|UniRef100A0A6P3G6R30_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['PYOOD']
# memid 0 PYOOD 9823
# uniprotid: 0 ['>tr|UniRef100A0A8D1L8I20|UniRef100A0A8D1L8I20_PYOOD/1-127 Memid:9823\n']
# test2
# updating outputs ['HTCVJ']
# memid 0 HTCVJ 31032
# uniprotid: 0 ['>tr|UniRef100H2SIP90|UniRef100H2SIP90_HTCVJ/1-127 Memid:31032\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100G5E6I90|UniRef100G5E6I90_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100UPI0006D8E19C0|UniRef100UPI0006D8E19C0_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0R3V40|UniRef100A0A6B0R3V40_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100E1BHL30|UniRef100E1BHL30_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['IKVVS']
# memid 0 IKVVS 9447
# uniprotid: 0 ['>tr|UniRef100UPI001E2684DB0|UniRef100UPI001E2684DB0_IKVVS/1-127 Memid:9447\n']
# test2
# updating outputs ['KDGNQ']
# memid 0 KDGNQ 48699
# uniprotid: 0 ['>tr|UniRef100UPI00072E15AD0|UniRef100UPI00072E15AD0_KDGNQ/1-127 Memid:48699\n']
# test2
# updating outputs ['I9JEG']
# memid 0 I9JEG 885580
# uniprotid: 0 ['>tr|UniRef100A0A091EER60|UniRef100A0A091EER60_I9JEG/1-127 Memid:885580\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0SEE70|UniRef100A0A6B0SEE70_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['R6OJP']
# memid 0 R6OJP 9470
# uniprotid: 0 ['>tr|UniRef100UPI00234DCD1F0|UniRef100UPI00234DCD1F0_R6OJP/1-127 Memid:9470\n']
# test2
# updating outputs ['LUJDW']
# memid 0 LUJDW 8467
# uniprotid: 0 ['>tr|UniRef100UPI0020958E7B0|UniRef100UPI0020958E7B0_LUJDW/1-127 Memid:8467\n']
# test2
# updating outputs ['Z2VQK']
# memid 0 Z2VQK 37293
# uniprotid: 0 ['>tr|UniRef100UPI000625F20F0|UniRef100UPI000625F20F0_Z2VQK/1-127 Memid:37293\n']
# test2
# updating outputs ['QBLOL']
# memid 0 QBLOL 8049
# uniprotid: 0 ['>tr|UniRef100A0A8C5AMD50|UniRef100A0A8C5AMD50_QBLOL/1-127 Memid:8049\n']
# test2
# updating outputs ['VZC2K']
# memid 0 VZC2K 30522
# uniprotid: 0 ['>tr|UniRef100UPI000F7D12CC0|UniRef100UPI000F7D12CC0_VZC2K/1-127 Memid:30522\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3H5F40|UniRef100A0A6P3H5F40_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['LYRR8']
# memid 0 LYRR8 55291
# uniprotid: 0 ['>tr|UniRef100A0A8X7X4W40|UniRef100A0A8X7X4W40_LYRR8/1-127 Memid:55291\n']
# test2
# updating outputs ['ZHESP']
# memid 0 ZHESP 495550
# uniprotid: 0 ['>tr|UniRef100A0A3N0YJD80|UniRef100A0A3N0YJD80_ZHESP/1-127 Memid:495550\n']
# test2
# updating outputs ['RRHPD']
# memid 0 RRHPD 109280
# uniprotid: 0 ['>tr|UniRef100A0A3Q2ZF610|UniRef100A0A3Q2ZF610_RRHPD/1-127 Memid:109280\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3I1960|UniRef100A0A6P3I1960_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['0TLHT']
# memid 0 0TLHT 10160
# uniprotid: 0 ['>tr|UniRef100A0A6P3FI680|UniRef100A0A6P3FI680_0TLHT/1-127 Memid:10160\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3I9J90|UniRef100A0A6P3I9J90_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['X5AO0']
# memid 0 X5AO0 27592
# uniprotid: 0 ['>tr|UniRef100A0A6P3HER80|UniRef100A0A6P3HER80_X5AO0/1-127 Memid:27592\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI000DBC9A890|UniRef100UPI000DBC9A890_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['2JCR1']
# memid 0 2JCR1 30521
# uniprotid: 0 ['>tr|UniRef100A0A8B9YV520|UniRef100A0A8B9YV520_2JCR1/1-127 Memid:30521\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI001D1304440|UniRef100UPI001D1304440_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0R9S30|UniRef100A0A6B0R9S30_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['TPJLX']
# memid 0 TPJLX 9402
# uniprotid: 0 ['>tr|UniRef100L5K2T60|UniRef100L5K2T60_TPJLX/1-127 Memid:9402\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI001E1B9B090|UniRef100UPI001E1B9B090_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['OCTGI']
# memid 0 OCTGI 9925
# uniprotid: 0 ['>tr|UniRef100G1DFR80|UniRef100G1DFR80_OCTGI/1-127 Memid:9925\n']
# test2
# updating outputs ['VZC2K']
# memid 0 VZC2K 30522
# uniprotid: 0 ['>tr|UniRef100UPI000F7D50FF0|UniRef100UPI000F7D50FF0_VZC2K/1-127 Memid:30522\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100UPI0006D8DEFF0|UniRef100UPI0006D8DEFF0_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['YHLNF']
# memid 0 YHLNF 10029
# uniprotid: 0 ['>tr|UniRef100G3HJY90|UniRef100G3HJY90_YHLNF/1-127 Memid:10029\n']
# test2
# updating outputs ['JT4G7']
# memid 0 JT4G7 7757
# uniprotid: 0 ['>tr|UniRef100S4RJC50|UniRef100S4RJC50_JT4G7/1-127 Memid:7757\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100UPI0007609D8D0|UniRef100UPI0007609D8D0_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['YRM8B']
# memid 0 YRM8B 80966
# uniprotid: 0 ['>tr|UniRef100UPI0022347B5A0|UniRef100UPI0022347B5A0_YRM8B/1-127 Memid:80966\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI001E1B78F10|UniRef100UPI001E1B78F10_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8J3A60|UniRef100L8J3A60_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['XZRFX']
# memid 0 XZRFX 106734
# uniprotid: 0 ['>tr|UniRef100A0A8C0H8K60|UniRef100A0A8C0H8K60_XZRFX/1-127 Memid:106734\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI001E1B7B2F0|UniRef100UPI001E1B7B2F0_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100G3N0F30|UniRef100G3N0F30_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['YRM8B']
# memid 0 YRM8B 80966
# uniprotid: 0 ['>tr|UniRef100UPI002234C79A0|UniRef100UPI002234C79A0_YRM8B/1-127 Memid:80966\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8IH250|UniRef100L8IH250_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['VSFQQ']
# memid 0 VSFQQ 7913
# uniprotid: 0 ['>tr|UniRef100UPI001B7EA60E0|UniRef100UPI001B7EA60E0_VSFQQ/1-127 Memid:7913\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8HY010|UniRef100L8HY010_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8IKL60|UniRef100L8IKL60_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0RGX10|UniRef100A0A6B0RGX10_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3HFB10|UniRef100A0A6P3HFB10_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3INL20|UniRef100A0A6P3INL20_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['SAKQ2']
# memid 0 SAKQ2 386614
# uniprotid: 0 ['>tr|UniRef100UPI0014029DB80|UniRef100UPI0014029DB80_SAKQ2/1-127 Memid:386614\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100UPI0006D915990|UniRef100UPI0006D915990_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['W9ALR']
# memid 0 W9ALR 93934
# uniprotid: 0 ['>tr|UniRef100A0A8C2T8C30|UniRef100A0A8C2T8C30_W9ALR/1-127 Memid:93934\n']
# test2
# updating outputs ['YHO3L']
# memid 0 YHO3L 55544
# uniprotid: 0 ['>tr|UniRef100A0A4D9EDC70|UniRef100A0A4D9EDC70_YHO3L/1-127 Memid:55544\n']
# test2
# updating outputs ['2JCR1']
# memid 0 2JCR1 30521
# uniprotid: 0 ['>tr|UniRef100A0A8B9YDS60|UniRef100A0A8B9YDS60_2JCR1/1-127 Memid:30521\n']
# test2
# updating outputs ['ES6DZ']
# memid 0 ES6DZ 7888
# uniprotid: 0 ['>tr|UniRef100UPI001CF9C2E80|UniRef100UPI001CF9C2E80_ES6DZ/1-127 Memid:7888\n']
# test2
# updating outputs ['2TYW5']
# memid 0 2TYW5 9903
# uniprotid: 0 ['>tr|UniRef100E1BL490|UniRef100E1BL490_2TYW5/1-127 Memid:9903\n']
# test2
# updating outputs ['XP6BJ']
# memid 0 XP6BJ 9483
# uniprotid: 0 ['>tr|UniRef100U3FPN10|UniRef100U3FPN10_XP6BJ/1-127 Memid:9483\n']
# test2
# updating outputs ['KICWN']
# memid 0 KICWN 286002
# uniprotid: 0 ['>tr|UniRef100UPI0021CBB9DB0|UniRef100UPI0021CBB9DB0_KICWN/1-127 Memid:286002\n']
# test2
# updating outputs ['CK3G2']
# memid 0 CK3G2 9915
# uniprotid: 0 ['>tr|UniRef100A0A6P5CZQ40|UniRef100A0A6P5CZQ40_CK3G2/1-127 Memid:9915\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI000DBC92C40|UniRef100UPI000DBC92C40_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8INP30|UniRef100L8INP30_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['3UOFO']
# memid 0 3UOFO 2587831
# uniprotid: 0 ['>tr|UniRef100UPI000E7751BA0|UniRef100UPI000E7751BA0_3UOFO/1-127 Memid:2587831\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3I8000|UniRef100A0A6P3I8000_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['IIVH7']
# memid 0 IIVH7 626378
# uniprotid: 0 ['>tr|UniRef100A0A7L3KA180|UniRef100A0A7L3KA180_IIVH7/1-127 Memid:626378\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100UPI0000EBC24C0|UniRef100UPI0000EBC24C0_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['EXHWC']
# memid 0 EXHWC 61221
# uniprotid: 0 ['>tr|UniRef100A0A8D2Q7590|UniRef100A0A8D2Q7590_EXHWC/1-127 Memid:61221\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100G3MWH40|UniRef100G3MWH40_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['4Q524']
# memid 0 4Q524 30611
# uniprotid: 0 ['>tr|UniRef100H0XW630|UniRef100H0XW630_4Q524/1-127 Memid:30611\n']
# test2
# updating outputs ['J80VC']
# memid 0 J80VC 7998
# uniprotid: 0 ['>tr|UniRef100A0A2D0QKY60|UniRef100A0A2D0QKY60_J80VC/1-127 Memid:7998\n']
# test2
# updating outputs ['XL8EJ']
# memid 0 XL8EJ 9657
# uniprotid: 0 ['>tr|UniRef100UPI001FD276C60|UniRef100UPI001FD276C60_XL8EJ/1-127 Memid:9657\n']
# test2
# updating outputs ['43DFX']
# memid 0 43DFX 1608454
# uniprotid: 0 ['>tr|UniRef100A0A671L7890|UniRef100A0A671L7890_43DFX/1-127 Memid:1608454\n']
# test2
# updating outputs ['CK3G2']
# memid 0 CK3G2 9915
# uniprotid: 0 ['>tr|UniRef100A0A6P5DA380|UniRef100A0A6P5DA380_CK3G2/1-127 Memid:9915\n']
# test2
# updating outputs ['2JCR1']
# memid 0 2JCR1 30521
# uniprotid: 0 ['>tr|UniRef100A0A8B9YE270|UniRef100A0A8B9YE270_2JCR1/1-127 Memid:30521\n']
# test2
# updating outputs ['IIVH7']
# memid 0 IIVH7 626378
# uniprotid: 0 ['>tr|UniRef100A0A7L3KRL10|UniRef100A0A7L3KRL10_IIVH7/1-127 Memid:626378\n']
# test2
# updating outputs ['CK3G2']
# memid 0 CK3G2 9915
# uniprotid: 0 ['>tr|UniRef100A0A6P5CE560|UniRef100A0A6P5CE560_CK3G2/1-127 Memid:9915\n']
# test2
# updating outputs ['Z4QBW']
# memid 0 Z4QBW 146911
# uniprotid: 0 ['>tr|UniRef100UPI00074FC0CD0|UniRef100UPI00074FC0CD0_Z4QBW/1-127 Memid:146911\n']
# test2
# updating outputs ['TPELM']
# memid 0 TPELM 27675
# uniprotid: 0 ['>tr|UniRef100UPI0018A0B5AA0|UniRef100UPI0018A0B5AA0_TPELM/1-127 Memid:27675\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3HSC80|UniRef100A0A6P3HSC80_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['GQZUY']
# memid 0 GQZUY 109293
# uniprotid: 0 ['>tr|UniRef100UPI00223DD9FC0|UniRef100UPI00223DD9FC0_GQZUY/1-127 Memid:109293\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3IYH80|UniRef100A0A6P3IYH80_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['BQNBU']
# memid 0 BQNBU 176946
# uniprotid: 0 ['>tr|UniRef100UPI000441AEB40|UniRef100UPI000441AEB40_BQNBU/1-127 Memid:176946\n']
# test2
# updating outputs ['IDJ8E']
# memid 0 IDJ8E 417921
# uniprotid: 0 ['>tr|UniRef100UPI00155DEAA20|UniRef100UPI00155DEAA20_IDJ8E/1-127 Memid:417921\n']
# test2
# updating outputs ['1SZSM']
# memid 0 1SZSM 367368
# uniprotid: 0 ['>tr|UniRef100A0A8C8S1W50|UniRef100A0A8C8S1W50_1SZSM/1-127 Memid:367368\n']
# test2
# updating outputs ['SR1XP']
# memid 0 SR1XP 28829
# uniprotid: 0 ['>tr|UniRef100UPI001CD8B1D70|UniRef100UPI001CD8B1D70_SR1XP/1-127 Memid:28829\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0QYW30|UniRef100A0A6B0QYW30_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100G3MXG10|UniRef100G3MXG10_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['ZQ4OV']
# memid 0 ZQ4OV 409849
# uniprotid: 0 ['>tr|UniRef100A0A3B4AGF60|UniRef100A0A3B4AGF60_ZQ4OV/1-127 Memid:409849\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI00042C9A5A0|UniRef100UPI00042C9A5A0_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['H3DSP']
# memid 0 H3DSP 447135
# uniprotid: 0 ['>tr|UniRef100UPI0020212F7A0|UniRef100UPI0020212F7A0_H3DSP/1-127 Memid:447135\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100E1BL100|UniRef100E1BL100_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['F5HOZ']
# memid 0 F5HOZ 94237
# uniprotid: 0 ['>tr|UniRef100A0A3Q4ASZ10|UniRef100A0A3Q4ASZ10_F5HOZ/1-127 Memid:94237\n']
# test2
# updating outputs ['O1PNX']
# memid 0 O1PNX 9974
# uniprotid: 0 ['>tr|UniRef100UPI0008132A3A0|UniRef100UPI0008132A3A0_O1PNX/1-127 Memid:9974\n']
# test2
# updating outputs ['VZC2K']
# memid 0 VZC2K 30522
# uniprotid: 0 ['>tr|UniRef100A0A4W2CGH50|UniRef100A0A4W2CGH50_VZC2K/1-127 Memid:30522\n']
# test2
# updating outputs ['ZBG0A']
# memid 0 ZBG0A 99837
# uniprotid: 0 ['>tr|UniRef100A0A8C9Q2G10|UniRef100A0A8C9Q2G10_ZBG0A/1-127 Memid:99837\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3GSI60|UniRef100A0A6P3GSI60_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['CK3G2']
# memid 0 CK3G2 9915
# uniprotid: 0 ['>tr|UniRef100A0A6P5CN520|UniRef100A0A6P5CN520_CK3G2/1-127 Memid:9915\n']
# test2
# updating outputs ['DJ5JT']
# memid 0 DJ5JT 8168
# uniprotid: 0 ['>tr|UniRef100A0A6A5FAP10|UniRef100A0A6A5FAP10_DJ5JT/1-127 Memid:8168\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3GMI70|UniRef100A0A6P3GMI70_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['DJRAK']
# memid 0 DJRAK 482537
# uniprotid: 0 ['>tr|UniRef100UPI0004D061840|UniRef100UPI0004D061840_DJRAK/1-127 Memid:482537\n']
# test2
# updating outputs ['PF1WB']
# memid 0 PF1WB 173247
# uniprotid: 0 ['>tr|UniRef100UPI0011133D830|UniRef100UPI0011133D830_PF1WB/1-127 Memid:173247\n']
# test2
# updating outputs ['X5AO0']
# memid 0 X5AO0 27592
# uniprotid: 0 ['>tr|UniRef100A0A6B0RX480|UniRef100A0A6B0RX480_X5AO0/1-127 Memid:27592\n']
# test2
# updating outputs ['JSQVC']
# memid 0 JSQVC 79628
# uniprotid: 0 ['>tr|UniRef100A0A7L3Z9140|UniRef100A0A7L3Z9140_JSQVC/1-127 Memid:79628\n']
# test2
# updating outputs ['0D1UT']
# memid 0 0D1UT 260995
# uniprotid: 0 ['>tr|UniRef100A0A6P8S1700|UniRef100A0A6P8S1700_0D1UT/1-127 Memid:260995\n']
# test2
# updating outputs ['CFG7Y']
# memid 0 CFG7Y 225400
# uniprotid: 0 ['>tr|UniRef100L5LYZ70|UniRef100L5LYZ70_CFG7Y/1-127 Memid:225400\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0S3R70|UniRef100A0A6B0S3R70_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['TFPPZ']
# memid 0 TFPPZ 56723
# uniprotid: 0 ['>tr|UniRef100A0A3Q3NHI00|UniRef100A0A3Q3NHI00_TFPPZ/1-127 Memid:56723\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8IJV10|UniRef100L8IJV10_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['WM4WH']
# memid 0 WM4WH 300413
# uniprotid: 0 ['>tr|UniRef100UPI00214E92EA0|UniRef100UPI00214E92EA0_WM4WH/1-127 Memid:300413\n']
# test2
# updating outputs ['PKRD5']
# memid 0 PKRD5 33584
# uniprotid: 0 ['>tr|UniRef100A0A7L2UEQ30|UniRef100A0A7L2UEQ30_PKRD5/1-127 Memid:33584\n']
# test2
# updating outputs ['WZACT']
# memid 0 WZACT 291302
# uniprotid: 0 ['>tr|UniRef100UPI0007A6E3A30|UniRef100UPI0007A6E3A30_WZACT/1-127 Memid:291302\n']
# test2
# updating outputs ['DJ5JT']
# memid 0 DJ5JT 8168
# uniprotid: 0 ['>tr|UniRef100UPI00196366F60|UniRef100UPI00196366F60_DJ5JT/1-127 Memid:8168\n']
# test2
# updating outputs ['ES6DZ']
# memid 0 ES6DZ 7888
# uniprotid: 0 ['>tr|UniRef100UPI001CF952960|UniRef100UPI001CF952960_ES6DZ/1-127 Memid:7888\n']
# test2
# updating outputs ['JMYR0']
# memid 0 JMYR0 160734
# uniprotid: 0 ['>tr|UniRef100UPI001C4A9FC20|UniRef100UPI001C4A9FC20_JMYR0/1-127 Memid:160734\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI000DBC6B4F0|UniRef100UPI000DBC6B4F0_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI000DBC9A100|UniRef100UPI000DBC9A100_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['JMYR0']
# memid 0 JMYR0 160734
# uniprotid: 0 ['>tr|UniRef100UPI001C4CD1A80|UniRef100UPI001C4CD1A80_JMYR0/1-127 Memid:160734\n']
# test2
# updating outputs ['8RD1K']
# memid 0 8RD1K 105023
# uniprotid: 0 ['>tr|UniRef100A0A9D2YPS50|UniRef100A0A9D2YPS50_8RD1K/1-127 Memid:105023\n']
# test2
# updating outputs ['TFJKB']
# memid 0 TFJKB 27794
# uniprotid: 0 ['>tr|UniRef100UPI001CA802EC0|UniRef100UPI001CA802EC0_TFJKB/1-127 Memid:27794\n']
# test2
# updating outputs ['AJXPI']
# memid 0 AJXPI 293821
# uniprotid: 0 ['>tr|UniRef100UPI0020D008FE0|UniRef100UPI0020D008FE0_AJXPI/1-127 Memid:293821\n']
# test2
# updating outputs ['SA3AF']
# memid 0 SA3AF 8469
# uniprotid: 0 ['>tr|UniRef100M7B0550|UniRef100M7B0550_SA3AF/1-127 Memid:8469\n']
# test2
# updating outputs ['D9IJG']
# memid 0 D9IJG 64802
# uniprotid: 0 ['>tr|UniRef100A0A7K7IH160|UniRef100A0A7K7IH160_D9IJG/1-127 Memid:64802\n']
# test2
# updating outputs ['SR1XP']
# memid 0 SR1XP 28829
# uniprotid: 0 ['>tr|UniRef100UPI001CD835D10|UniRef100UPI001CD835D10_SR1XP/1-127 Memid:28829\n']
# test2
# updating outputs ['QW1UC']
# memid 0 QW1UC 310571
# uniprotid: 0 ['>tr|UniRef100UPI001445D6C20|UniRef100UPI001445D6C20_QW1UC/1-127 Memid:310571\n']
# test2
# updating outputs ['PTAJH']
# memid 0 PTAJH 379532
# uniprotid: 0 ['>tr|UniRef100UPI00063EEA3E0|UniRef100UPI00063EEA3E0_PTAJH/1-127 Memid:379532\n']
# test2
# updating outputs ['UJGDZ']
# memid 0 UJGDZ 101364
# uniprotid: 0 ['>tr|UniRef100UPI00227965EA0|UniRef100UPI00227965EA0_UJGDZ/1-127 Memid:101364\n']
# test2
# updating outputs ['YRWLZ']
# memid 0 YRWLZ 9838
# uniprotid: 0 ['>tr|UniRef100A0A5N4CSI10|UniRef100A0A5N4CSI10_YRWLZ/1-127 Memid:9838\n']
# test2
# updating outputs ['NHVZR']
# memid 0 NHVZR 9365
# uniprotid: 0 ['>tr|UniRef100A0A1S2ZX760|UniRef100A0A1S2ZX760_NHVZR/1-127 Memid:9365\n']
# test2
# updating outputs ['JMYR0']
# memid 0 JMYR0 160734
# uniprotid: 0 ['>tr|UniRef100UPI001C4AB5500|UniRef100UPI001C4AB5500_JMYR0/1-127 Memid:160734\n']
# test2
# updating outputs ['O1PNX']
# memid 0 O1PNX 9974
# uniprotid: 0 ['>tr|UniRef100UPI0008138BE40|UniRef100UPI0008138BE40_O1PNX/1-127 Memid:9974\n']
# test2
# updating outputs ['X5AO0']
# memid 0 X5AO0 27592
# uniprotid: 0 ['>tr|UniRef100A0A6P3IR620|UniRef100A0A6P3IR620_X5AO0/1-127 Memid:27592\n']
# test2
# updating outputs ['VZC2K']
# memid 0 VZC2K 30522
# uniprotid: 0 ['>tr|UniRef100A0A4W2E9V80|UniRef100A0A4W2E9V80_VZC2K/1-127 Memid:30522\n']
# test2
# updating outputs ['VZC2K']
# memid 0 VZC2K 30522
# uniprotid: 0 ['>tr|UniRef100A0A4W2HDW20|UniRef100A0A4W2HDW20_VZC2K/1-127 Memid:30522\n']
# test2
# updating outputs ['QPREN']
# memid 0 QPREN 9978
# uniprotid: 0 ['>tr|UniRef100UPI001788C8EF0|UniRef100UPI001788C8EF0_QPREN/1-127 Memid:9978\n']
# test2
# updating outputs ['WO9H1']
# memid 0 WO9H1 52904
# uniprotid: 0 ['>tr|UniRef100A0A6A4RRA80|UniRef100A0A6A4RRA80_WO9H1/1-127 Memid:52904\n']
# test2
# updating outputs ['BBMRF']
# memid 0 BBMRF 390379
# uniprotid: 0 ['>tr|UniRef100UPI00147123600|UniRef100UPI00147123600_BBMRF/1-127 Memid:390379\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8ILY70|UniRef100L8ILY70_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['HJOCN']
# memid 0 HJOCN 8218
# uniprotid: 0 ['>tr|UniRef100A0A6P8UND50|UniRef100A0A6P8UND50_HJOCN/1-127 Memid:8218\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100G3MXG70|UniRef100G3MXG70_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['GPRVC']
# memid 0 GPRVC 192404
# uniprotid: 0 ['>tr|UniRef100UPI001879DA240|UniRef100UPI001879DA240_GPRVC/1-127 Memid:192404\n']
# test2
# updating outputs ['U1DTF']
# memid 0 U1DTF 9886
# uniprotid: 0 ['>tr|UniRef100A0A5N3VZ980|UniRef100A0A5N3VZ980_U1DTF/1-127 Memid:9886\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100A0A8J8YR800|UniRef100A0A8J8YR800_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['PXHZI']
# memid 0 PXHZI 143302
# uniprotid: 0 ['>tr|UniRef100UPI0003345E950|UniRef100UPI0003345E950_PXHZI/1-127 Memid:143302\n']
# test2
# updating outputs ['H2SVZ']
# memid 0 H2SVZ 337641
# uniprotid: 0 ['>tr|UniRef100A0A9D3SBP50|UniRef100A0A9D3SBP50_H2SVZ/1-127 Memid:337641\n']
# test2
# updating outputs ['SZ0TN']
# memid 0 SZ0TN 31138
# uniprotid: 0 ['>tr|UniRef100UPI0015554E390|UniRef100UPI0015554E390_SZ0TN/1-127 Memid:31138\n']
# test2
# updating outputs ['UFJTV']
# memid 0 UFJTV 685728
# uniprotid: 0 ['>tr|UniRef100UPI00223D1AB30|UniRef100UPI00223D1AB30_UFJTV/1-127 Memid:685728\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100E1BAA60|UniRef100E1BAA60_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['AKICW']
# memid 0 AKICW 109475
# uniprotid: 0 ['>tr|UniRef100UPI002110BE780|UniRef100UPI002110BE780_AKICW/1-127 Memid:109475\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100E1BM220|UniRef100E1BM220_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['IQEGZ']
# memid 0 IQEGZ 99487
# uniprotid: 0 ['>tr|UniRef100UPI002116F9350|UniRef100UPI002116F9350_IQEGZ/1-127 Memid:99487\n']
# test2
# updating outputs ['QUHYM']
# memid 0 QUHYM 591936
# uniprotid: 0 ['>tr|UniRef100UPI00130176650|UniRef100UPI00130176650_QUHYM/1-127 Memid:591936\n']
# test2
# updating outputs ['XWJXT']
# memid 0 XWJXT 27687
# uniprotid: 0 ['>tr|UniRef100A0A8C4TGE40|UniRef100A0A8C4TGE40_XWJXT/1-127 Memid:27687\n']
# test2
# updating outputs ['ES6DZ']
# memid 0 ES6DZ 7888
# uniprotid: 0 ['>tr|UniRef100UPI001CFA77F50|UniRef100UPI001CFA77F50_ES6DZ/1-127 Memid:7888\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI001D1169280|UniRef100UPI001D1169280_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['CJIP1']
# memid 0 CJIP1 43346
# uniprotid: 0 ['>tr|UniRef100A0A6P3J4X70|UniRef100A0A6P3J4X70_CJIP1/1-127 Memid:43346\n']
# test2
# updating outputs ['PTAJH']
# memid 0 PTAJH 379532
# uniprotid: 0 ['>tr|UniRef100UPI00063F606C0|UniRef100UPI00063F606C0_PTAJH/1-127 Memid:379532\n']
# test2
# updating outputs ['NHRGR']
# memid 0 NHRGR 491861
# uniprotid: 0 ['>tr|UniRef100UPI00109EFE780|UniRef100UPI00109EFE780_NHRGR/1-127 Memid:491861\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8IRG90|UniRef100L8IRG90_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['TMV0Z']
# memid 0 TMV0Z 13397
# uniprotid: 0 ['>tr|UniRef100UPI001B7EE9830|UniRef100UPI001B7EE9830_TMV0Z/1-127 Memid:13397\n']
# test2
# updating outputs ['ER3DV']
# memid 0 ER3DV 241271
# uniprotid: 0 ['>tr|UniRef100UPI001BD3E0A30|UniRef100UPI001BD3E0A30_ER3DV/1-127 Memid:241271\n']
# test2
# updating outputs ['MJHYB']
# memid 0 MJHYB 8508
# uniprotid: 0 ['>tr|UniRef100A0A8D0HNC30|UniRef100A0A8D0HNC30_MJHYB/1-127 Memid:8508\n']
# test2
# updating outputs ['SAKQ2']
# memid 0 SAKQ2 386614
# uniprotid: 0 ['>tr|UniRef100UPI00140330650|UniRef100UPI00140330650_SAKQ2/1-127 Memid:386614\n']
# test2
# updating outputs ['SCUXN']
# memid 0 SCUXN 34773
# uniprotid: 0 ['>tr|UniRef100UPI001BF400CD0|UniRef100UPI001BF400CD0_SCUXN/1-127 Memid:34773\n']
# test2
# updating outputs ['XP6BJ']
# memid 0 XP6BJ 9483
# uniprotid: 0 ['>tr|UniRef100F7FGM20|UniRef100F7FGM20_XP6BJ/1-127 Memid:9483\n']
# test2
# updating outputs ['APR06']
# memid 0 APR06 89399
# uniprotid: 0 ['>tr|UniRef100UPI00094435040|UniRef100UPI00094435040_APR06/1-127 Memid:89399\n']
# test2
# updating outputs ['67HQN']
# memid 0 67HQN 7962
# uniprotid: 0 ['>tr|UniRef100A0A8C1SI860|UniRef100A0A8C1SI860_67HQN/1-127 Memid:7962\n']
# test2
# updating outputs ['PXSWJ']
# memid 0 PXSWJ 259920
# uniprotid: 0 ['>tr|UniRef100UPI00202E185E0|UniRef100UPI00202E185E0_PXSWJ/1-127 Memid:259920\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100G3N0M90|UniRef100G3N0M90_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['UEOBI']
# memid 0 UEOBI 80972
# uniprotid: 0 ['>tr|UniRef100A0A3Q1B3220|UniRef100A0A3Q1B3220_UEOBI/1-127 Memid:80972\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0R2I80|UniRef100A0A6B0R2I80_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['RSZRP']
# memid 0 RSZRP 185453
# uniprotid: 0 ['>tr|UniRef100A0A9B0WSL20|UniRef100A0A9B0WSL20_RSZRP/1-127 Memid:185453\n']
# test2
# updating outputs ['FUK1F']
# memid 0 FUK1F 68415
# uniprotid: 0 ['>tr|UniRef100A0A8C6DH080|UniRef100A0A8C6DH080_FUK1F/1-127 Memid:68415\n']
# test2
# updating outputs ['VZC2K']
# memid 0 VZC2K 30522
# uniprotid: 0 ['>tr|UniRef100UPI000F7D0B470|UniRef100UPI000F7D0B470_VZC2K/1-127 Memid:30522\n']
# test2
# updating outputs ['YRM8B']
# memid 0 YRM8B 80966
# uniprotid: 0 ['>tr|UniRef100UPI00223471A80|UniRef100UPI00223471A80_YRM8B/1-127 Memid:80966\n']
# test2
# updating outputs ['GQZUY']
# memid 0 GQZUY 109293
# uniprotid: 0 ['>tr|UniRef100UPI00223E3AD60|UniRef100UPI00223E3AD60_GQZUY/1-127 Memid:109293\n']
# test2
# updating outputs ['BBMRF']
# memid 0 BBMRF 390379
# uniprotid: 0 ['>tr|UniRef100UPI00147171D50|UniRef100UPI00147171D50_BBMRF/1-127 Memid:390379\n']
# test2
# updating outputs ['OJYG2']
# memid 0 OJYG2 29064
# uniprotid: 0 ['>tr|UniRef100UPI0020FF99810|UniRef100UPI0020FF99810_OJYG2/1-127 Memid:29064\n']
# test2
# updating outputs ['ZFGKB']
# memid 0 ZFGKB 13146
# uniprotid: 0 ['>tr|UniRef100A0A8C6JX770|UniRef100A0A8C6JX770_ZFGKB/1-127 Memid:13146\n']
# test2
# updating outputs ['SXK5G']
# memid 0 SXK5G 1868482
# uniprotid: 0 ['>tr|UniRef100A0A3Q0ECJ60|UniRef100A0A3Q0ECJ60_SXK5G/1-127 Memid:1868482\n']
# test2
# updating outputs ['2TYW5']
# memid 0 2TYW5 9903
# uniprotid: 0 ['>tr|UniRef100A0A8B9WKI20|UniRef100A0A8B9WKI20_2TYW5/1-127 Memid:9903\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0RHM90|UniRef100A0A6B0RHM90_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['HUZIG']
# memid 0 HUZIG 375764
# uniprotid: 0 ['>tr|UniRef100A0A673CB540|UniRef100A0A673CB540_HUZIG/1-127 Memid:375764\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100E1B8960|UniRef100E1B8960_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['XZRFX']
# memid 0 XZRFX 106734
# uniprotid: 0 ['>tr|UniRef100UPI0013F182ED0|UniRef100UPI0013F182ED0_XZRFX/1-127 Memid:106734\n']
# test2
# updating outputs ['2TYW5']
# memid 0 2TYW5 9903
# uniprotid: 0 ['>tr|UniRef100A0A6P5C6F00|UniRef100A0A6P5C6F00_2TYW5/1-127 Memid:9903\n']
# test2
# updating outputs ['QW1RM']
# memid 0 QW1RM 161584
# uniprotid: 0 ['>tr|UniRef100UPI001885B2850|UniRef100UPI001885B2850_QW1RM/1-127 Memid:161584\n']
# test2
# updating outputs ['VSFQQ']
# memid 0 VSFQQ 7913
# uniprotid: 0 ['>tr|UniRef100UPI001B7F3F190|UniRef100UPI001B7F3F190_VSFQQ/1-127 Memid:7913\n']
# test2
# updating outputs ['SXK5G']
# memid 0 SXK5G 1868482
# uniprotid: 0 ['>tr|UniRef100A0A1U7T3I30|UniRef100A0A1U7T3I30_SXK5G/1-127 Memid:1868482\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI001D10C0EB0|UniRef100UPI001D10C0EB0_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8J5F00|UniRef100L8J5F00_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['NHVZR']
# memid 0 NHVZR 9365
# uniprotid: 0 ['>tr|UniRef100A0A1S3AIS40|UniRef100A0A1S3AIS40_NHVZR/1-127 Memid:9365\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100F1N6G10|UniRef100F1N6G10_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['OMIFC']
# memid 0 OMIFC 36176
# uniprotid: 0 ['>tr|UniRef100UPI001CB7C3730|UniRef100UPI001CB7C3730_OMIFC/1-127 Memid:36176\n']
# test2
# updating outputs ['GDHXY']
# memid 0 GDHXY 69293
# uniprotid: 0 ['>tr|UniRef100G3PLN10|UniRef100G3PLN10_GDHXY/1-127 Memid:69293\n']
# test2
# updating outputs ['BT4TK']
# memid 0 BT4TK 221966
# uniprotid: 0 ['>tr|UniRef100A0A7L3E5T90|UniRef100A0A7L3E5T90_BT4TK/1-127 Memid:221966\n']
# test2
# updating outputs ['BYQQS']
# memid 0 BYQQS 215358
# uniprotid: 0 ['>tr|UniRef100UPI000F5EAFAA0|UniRef100UPI000F5EAFAA0_BYQQS/1-127 Memid:215358\n']
# test2
# updating outputs ['ZLUBP']
# memid 0 ZLUBP 279965
# uniprotid: 0 ['>tr|UniRef100UPI0010A98D0A0|UniRef100UPI0010A98D0A0_ZLUBP/1-127 Memid:279965\n']
# test2
# updating outputs ['RRHPD']
# memid 0 RRHPD 109280
# uniprotid: 0 ['>tr|UniRef100A0A3Q2YEV20|UniRef100A0A3Q2YEV20_RRHPD/1-127 Memid:109280\n']
# test2
# updating outputs ['RTQ2A']
# memid 0 RTQ2A 36200
# uniprotid: 0 ['>tr|UniRef100A0A7J5Z8530|UniRef100A0A7J5Z8530_RTQ2A/1-127 Memid:36200\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8IQ700|UniRef100L8IQ700_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['LUJDW']
# memid 0 LUJDW 8467
# uniprotid: 0 ['>tr|UniRef100UPI00209482490|UniRef100UPI00209482490_LUJDW/1-127 Memid:8467\n']
# test2
# updating outputs ['OB88P']
# memid 0 OB88P 9601
# uniprotid: 0 ['>tr|UniRef100UPI000CEF9FF50|UniRef100UPI000CEF9FF50_OB88P/1-127 Memid:9601\n']
# test2
# updating outputs ['SAKQ2']
# memid 0 SAKQ2 386614
# uniprotid: 0 ['>tr|UniRef100UPI001401C1650|UniRef100UPI001401C1650_SAKQ2/1-127 Memid:386614\n']
# test2
# updating outputs ['U9HWH']
# memid 0 U9HWH 63155
# uniprotid: 0 ['>tr|UniRef100UPI0011EA503A0|UniRef100UPI0011EA503A0_U9HWH/1-127 Memid:63155\n']
# test2
# updating outputs ['EH37C']
# memid 0 EH37C 121402
# uniprotid: 0 ['>tr|UniRef100A0A8T2P6120|UniRef100A0A8T2P6120_EH37C/1-127 Memid:121402\n']
# test2
# updating outputs ['R6OJP']
# memid 0 R6OJP 9470
# uniprotid: 0 ['>tr|UniRef100UPI00234D6D720|UniRef100UPI00234D6D720_R6OJP/1-127 Memid:9470\n']
# test2
# updating outputs ['ZMWN3']
# memid 0 ZMWN3 9749
# uniprotid: 0 ['>tr|UniRef100A0A2Y9MLH30|UniRef100A0A2Y9MLH30_ZMWN3/1-127 Memid:9749\n']
# test2
# updating outputs ['OMIFC']
# memid 0 OMIFC 36176
# uniprotid: 0 ['>tr|UniRef100UPI001CB878A20|UniRef100UPI001CB878A20_OMIFC/1-127 Memid:36176\n']
# test2
# updating outputs ['TPELM']
# memid 0 TPELM 27675
# uniprotid: 0 ['>tr|UniRef100UPI00189F2B1D0|UniRef100UPI00189F2B1D0_TPELM/1-127 Memid:27675\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0R7M20|UniRef100A0A6B0R7M20_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100G5E6T50|UniRef100G5E6T50_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['REV7Q']
# memid 0 REV7Q 10181
# uniprotid: 0 ['>tr|UniRef100G5C0U80|UniRef100G5C0U80_REV7Q/1-127 Memid:10181\n']
# test2
# updating outputs ['UU6S5']
# memid 0 UU6S5 89462
# uniprotid: 0 ['>tr|UniRef100UPI001D0F856A0|UniRef100UPI001D0F856A0_UU6S5/1-127 Memid:89462\n']
# test2
# updating outputs ['PYOOD']
# memid 0 PYOOD 9823
# uniprotid: 0 ['>tr|UniRef100A0A8D0P6Q30|UniRef100A0A8D0P6Q30_PYOOD/1-127 Memid:9823\n']
# test2
# updating outputs ['LBET1']
# memid 0 LBET1 2652724
# uniprotid: 0 ['>tr|UniRef100A0A913WU150|UniRef100A0A913WU150_LBET1/1-127 Memid:2652724\n']
# test2
# updating outputs ['LOCHB']
# memid 0 LOCHB 9689
# uniprotid: 0 ['>tr|UniRef100A0A8C9D8320|UniRef100A0A8C9D8320_LOCHB/1-127 Memid:9689\n']
# test2
# updating outputs ['D9IJG']
# memid 0 D9IJG 64802
# uniprotid: 0 ['>tr|UniRef100A0A7K7J3G60|UniRef100A0A7K7J3G60_D9IJG/1-127 Memid:64802\n']
# test2
# updating outputs ['TMV0Z']
# memid 0 TMV0Z 13397
# uniprotid: 0 ['>tr|UniRef100UPI001B7EEB360|UniRef100UPI001B7EEB360_TMV0Z/1-127 Memid:13397\n']
# test2
# updating outputs ['VUCM9']
# memid 0 VUCM9 1234261
# uniprotid: 0 ['>tr|UniRef100A0A814D4J20|UniRef100A0A814D4J20_VUCM9/1-127 Memid:1234261\n']
# test2
# updating outputs ['XWJXT']
# memid 0 XWJXT 27687
# uniprotid: 0 ['>tr|UniRef100A0A8C4RWG40|UniRef100A0A8C4RWG40_XWJXT/1-127 Memid:27687\n']
# test2
# updating outputs ['RZFAZ']
# memid 0 RZFAZ 79684
# uniprotid: 0 ['>tr|UniRef100A0A8J6KR670|UniRef100A0A8J6KR670_RZFAZ/1-127 Memid:79684\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100L8ID330|UniRef100L8ID330_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['UDOTC']
# memid 0 UDOTC 84645
# uniprotid: 0 ['>tr|UniRef100UPI0021E237840|UniRef100UPI0021E237840_UDOTC/1-127 Memid:84645\n']
# test2
# updating outputs ['VE3VQ']
# memid 0 VE3VQ 8040
# uniprotid: 0 ['>tr|UniRef100A0A8U0Q1H90|UniRef100A0A8U0Q1H90_VE3VQ/1-127 Memid:8040\n']
# test2
# updating outputs ['N1UGK']
# memid 0 N1UGK 9986
# uniprotid: 0 ['>tr|UniRef100G1U5310|UniRef100G1U5310_N1UGK/1-127 Memid:9986\n']
# test2
# updating outputs ['BYQQS']
# memid 0 BYQQS 215358
# uniprotid: 0 ['>tr|UniRef100UPI000F5E10100|UniRef100UPI000F5E10100_BYQQS/1-127 Memid:215358\n']
# test2
# updating outputs ['0TLHT']
# memid 0 0TLHT 10160
# uniprotid: 0 ['>tr|UniRef100A0A6P3VAX50|UniRef100A0A6P3VAX50_0TLHT/1-127 Memid:10160\n']
# test2
# updating outputs ['WPRTJ']
# memid 0 WPRTJ 45351
# uniprotid: 0 ['>tr|UniRef100A7RJL30|UniRef100A7RJL30_WPRTJ/1-127 Memid:45351\n']
# test2
# updating outputs ['UFJTV']
# memid 0 UFJTV 685728
# uniprotid: 0 ['>tr|UniRef100UPI00223D443C0|UniRef100UPI00223D443C0_UFJTV/1-127 Memid:685728\n']
# test2
# updating outputs ['ER3DV']
# memid 0 ER3DV 241271
# uniprotid: 0 ['>tr|UniRef100UPI001BD5543E0|UniRef100UPI001BD5543E0_ER3DV/1-127 Memid:241271\n']
# test2
# updating outputs ['DPMDM']
# memid 0 DPMDM 9913
# uniprotid: 0 ['>tr|UniRef100E1B7N80|UniRef100E1B7N80_DPMDM/1-127 Memid:9913\n']
# test2
# updating outputs ['CLTNE']
# memid 0 CLTNE 27706
# uniprotid: 0 ['>tr|UniRef100UPI0018ED30670|UniRef100UPI0018ED30670_CLTNE/1-127 Memid:27706\n']
# test2
# updating outputs ['YQNNI']
# memid 0 YQNNI 37032
# uniprotid: 0 ['>tr|UniRef100UPI00115530500|UniRef100UPI00115530500_YQNNI/1-127 Memid:37032\n']
# test2
# updating outputs ['CQLR9']
# memid 0 CQLR9 9764
# uniprotid: 0 ['>tr|UniRef100A0A2F0BBX10|UniRef100A0A2F0BBX10_CQLR9/1-127 Memid:9764\n']
# test2
# updating outputs ['UFD9A']
# memid 0 UFD9A 2664684
# uniprotid: 0 ['>tr|UniRef100A0A7I8WCF20|UniRef100A0A7I8WCF20_UFD9A/1-127 Memid:2664684\n']
# test2
# updating outputs ['KIB16']
# memid 0 KIB16 7897
# uniprotid: 0 ['>tr|UniRef100H3A2S80|UniRef100H3A2S80_KIB16/1-127 Memid:7897\n']
# test2
# updating outputs ['UFJTV']
# memid 0 UFJTV 685728
# uniprotid: 0 ['>tr|UniRef100UPI00223E51230|UniRef100UPI00223E51230_UFJTV/1-127 Memid:685728\n']
# test2
# updating outputs ['U7Q9Q']
# memid 0 U7Q9Q 13346
# uniprotid: 0 ['>tr|UniRef100A0A5N5TAT80|UniRef100A0A5N5TAT80_U7Q9Q/1-127 Memid:13346\n']
# test2
# updating outputs ['BQNBU']
# memid 0 BQNBU 176946
# uniprotid: 0 ['>tr|UniRef100UPI00044236E50|UniRef100UPI00044236E50_BQNBU/1-127 Memid:176946\n']
# test2
# updating outputs ['XZM25']
# memid 0 XZM25 118797
# uniprotid: 0 ['>tr|UniRef100A0A340YCC00|UniRef100A0A340YCC00_XZM25/1-127 Memid:118797\n']
# test2
# updating outputs ['WZJYF']
# memid 0 WZJYF 8630
# uniprotid: 0 ['>tr|UniRef100A0A8C5RA240|UniRef100A0A8C5RA240_WZJYF/1-127 Memid:8630\n']
# test2
# updating outputs ['MRY7E']
# memid 0 MRY7E 30033
# uniprotid: 0 ['>tr|UniRef100A0A6P4I2P00|UniRef100A0A6P4I2P00_MRY7E/1-127 Memid:30033\n']
# test2
# updating outputs ['OW7DZ']
# memid 0 OW7DZ 37621
# uniprotid: 0 ['>tr|UniRef100UPI000719ADCE0|UniRef100UPI000719ADCE0_OW7DZ/1-127 Memid:37621\n']
# test2
# updating outputs ['UDTNK']
# memid 0 UDTNK 6359
# uniprotid: 0 ['>tr|UniRef100P193740|UniRef100P193740_UDTNK/1-127 Memid:6359\n']
# test2
# updating outputs ['ES6DZ']
# memid 0 ES6DZ 7888
# uniprotid: 0 ['>tr|UniRef100UPI001CF9C10A0|UniRef100UPI001CF9C10A0_ES6DZ/1-127 Memid:7888\n']
# test2
# updating outputs ['VUQVS']
# memid 0 VUQVS 37623
# uniprotid: 0 ['>tr|UniRef100UPI002094E5220|UniRef100UPI002094E5220_VUQVS/1-127 Memid:37623\n']
# test2
# updating outputs ['IQU4U']
# memid 0 IQU4U 181472
# uniprotid: 0 ['>tr|UniRef100UPI0011764C380|UniRef100UPI0011764C380_IQU4U/1-127 Memid:181472\n']
# test2
# updating outputs ['LGAA2']
# memid 0 LGAA2 7830
# uniprotid: 0 ['>tr|UniRef100UPI0018F398150|UniRef100UPI0018F398150_LGAA2/1-127 Memid:7830\n']
# test2
# updating outputs ['OB88P']
# memid 0 OB88P 9601
# uniprotid: 0 ['>tr|UniRef100H2PI790|UniRef100H2PI790_OB88P/1-127 Memid:9601\n']
# test2
# updating outputs ['IKVVS']
# memid 0 IKVVS 9447
# uniprotid: 0 ['>tr|UniRef100UPI001E266A810|UniRef100UPI001E266A810_IKVVS/1-127 Memid:9447\n']
# test2
# updating outputs ['RXVCR']
# memid 0 RXVCR 7906
# uniprotid: 0 ['>tr|UniRef100UPI001560087B0|UniRef100UPI001560087B0_RXVCR/1-127 Memid:7906\n']
# test2
# updating outputs ['R3GJ0']
# memid 0 R3GJ0 72004
# uniprotid: 0 ['>tr|UniRef100A0A6B0RJJ70|UniRef100A0A6B0RJJ70_R3GJ0/1-127 Memid:72004\n']
# test2
# updating outputs ['WPRTJ']
# memid 0 WPRTJ 45351
# uniprotid: 0 ['>tr|UniRef100A7SHX40|UniRef100A7SHX40_WPRTJ/1-127 Memid:45351\n']
# test2
# updating outputs ['LGAA2']
# memid 0 LGAA2 7830
# uniprotid: 0 ['>tr|UniRef100UPI0018F46ADD0|UniRef100UPI0018F46ADD0_LGAA2/1-127 Memid:7830\n']
# test2
# updating outputs ['43DFX']
# memid 0 43DFX 1608454
# uniprotid: 0 ['>tr|UniRef100UPI0007BAD0F40|UniRef100UPI0007BAD0F40_43DFX/1-127 Memid:1608454\n']
# test2
# updating outputs ['ZFZQA']
# memid 0 ZFZQA 6412
# uniprotid: 0 ['>tr|UniRef100T1FNJ30|UniRef100T1FNJ30_ZFZQA/1-127 Memid:6412\n']
# test2
# updating outputs ['19ELO']
# memid 0 19ELO 59479
# uniprotid: 0 ['>tr|UniRef100A0A671FPC20|UniRef100A0A671FPC20_19ELO/1-127 Memid:59479\n']
# test2
# updating outputs ['K43SE']
# memid 0 K43SE 7176
# uniprotid: 0 ['>tr|UniRef100B0X7740|UniRef100B0X7740_K43SE/1-127 Memid:7176\n']
# test2
# updating outputs ['TJH9R']
# memid 0 TJH9R 186990
# uniprotid: 0 ['>tr|UniRef100A0A8B7QKP00|UniRef100A0A8B7QKP00_TJH9R/1-127 Memid:186990\n']
# test2
# updating outputs ['0ETJH']
# memid 0 0ETJH 9515
# uniprotid: 0 ['>tr|UniRef100A0A6J3H3M10|UniRef100A0A6J3H3M10_0ETJH/1-127 Memid:9515\n']
# test2
# updating outputs ['INYZR']
# memid 0 INYZR 31234
# uniprotid: 0 ['>tr|UniRef100A0A6A5GDS60|UniRef100A0A6A5GDS60_INYZR/1-127 Memid:31234\n']
# test2
# updating outputs ['6YNW7']
# memid 0 6YNW7 30608
# uniprotid: 0 ['>tr|UniRef100A0A8B7EQU10|UniRef100A0A8B7EQU10_6YNW7/1-127 Memid:30608\n']
# test2
# updating outputs ['A04TT']
# memid 0 A04TT 6550
# uniprotid: 0 ['>tr|UniRef100A0A8S3QB230|UniRef100A0A8S3QB230_A04TT/1-127 Memid:6550\n']
# test2
# updating outputs ['ZKPSS']
# memid 0 ZKPSS 111125
# uniprotid: 0 ['>tr|UniRef100A0A821KVG90|UniRef100A0A821KVG90_ZKPSS/1-127 Memid:111125\n']
# test2
# updating outputs ['RROGU']
# memid 0 RROGU 283035
# uniprotid: 0 ['>tr|UniRef100UPI00125DD02F0|UniRef100UPI00125DD02F0_RROGU/1-127 Memid:283035\n']
# test2
# updating outputs ['SAKQ2']
# memid 0 SAKQ2 386614
# uniprotid: 0 ['>tr|UniRef100UPI0014036BE10|UniRef100UPI0014036BE10_SAKQ2/1-127 Memid:386614\n']
# test2
# updating outputs ['VBRW6']
# memid 0 VBRW6 6347
# uniprotid: 0 ['>tr|UniRef100A0A8S4PEG10|UniRef100A0A8S4PEG10_VBRW6/1-127 Memid:6347\n']
# test2
# updating outputs ['ZFZQA']
# memid 0 ZFZQA 6412
# uniprotid: 0 ['>tr|UniRef100C7ENF60|UniRef100C7ENF60_ZFZQA/1-127 Memid:6412\n']
# test2
# updating outputs ['THLYR']
# memid 0 THLYR 6446
# uniprotid: 0 ['>tr|UniRef100P307570|UniRef100P307570_THLYR/1-127 Memid:6446\n']
# test2
# updating outputs ['Z2VQK']
# memid 0 Z2VQK 37293
# uniprotid: 0 ['>tr|UniRef100UPI000B5123F80|UniRef100UPI000B5123F80_Z2VQK/1-127 Memid:37293\n']
# test2
# updating outputs ['ITZW9']
# memid 0 ITZW9 73337
# uniprotid: 0 ['>tr|UniRef100UPI0002C6333A0|UniRef100UPI0002C6333A0_ITZW9/1-127 Memid:73337\n']
# test2
# updating outputs ['LBET1']
# memid 0 LBET1 2652724
# uniprotid: 0 ['>tr|UniRef100A0A913X6980|UniRef100A0A913X6980_LBET1/1-127 Memid:2652724\n']
# test2
# updating outputs ['F7ZAL']
# memid 0 F7ZAL 6326
# uniprotid: 0 ['>tr|UniRef100A0A1I7S5X90|UniRef100A0A1I7S5X90_F7ZAL/1-127 Memid:6326\n']
# test2
# updating outputs ['ROZNY']
# memid 0 ROZNY 6850
# uniprotid: 0 ['>tr|UniRef100UPI0006B0B1180|UniRef100UPI0006B0B1180_ROZNY/1-127 Memid:6850\n']
# test2
# updating outputs ['1DH16']
# memid 0 1DH16 115357
# uniprotid: 0 ['>tr|UniRef100UPI001E277C540|UniRef100UPI001E277C540_1DH16/1-127 Memid:115357\n']
# test2
# updating outputs ['NHBA3']
# memid 0 NHBA3 9733
# uniprotid: 0 ['>tr|UniRef100UPI0002BCE5E00|UniRef100UPI0002BCE5E00_NHBA3/1-127 Memid:9733\n']
# test2
# updating outputs ['JRRNN']
# memid 0 JRRNN 1813166
# uniprotid: 0 ['>tr|UniRef100A0A142CCT10|UniRef100A0A142CCT10_JRRNN/1-127 Memid:1813166\n']
# test2
# updating outputs ['PTAJH']
# memid 0 PTAJH 379532
# uniprotid: 0 ['>tr|UniRef100UPI00063EE1F20|UniRef100UPI00063EE1F20_PTAJH/1-127 Memid:379532\n']
# test2
# updating outputs ['CBFA7']
# memid 0 CBFA7 36100
# uniprotid: 0 ['>tr|UniRef100UPI001EE5CAAE0|UniRef100UPI001EE5CAAE0_CBFA7/1-127 Memid:36100\n']
# test2
# updating outputs ['K36J9']
# memid 0 K36J9 7238
# uniprotid: 0 ['>tr|UniRef100B4IMA80|UniRef100B4IMA80_K36J9/1-127 Memid:7238\n']
# test2
# updating outputs ['RXVCR']
# memid 0 RXVCR 7906
# uniprotid: 0 ['>tr|UniRef100A0A444UKM60|UniRef100A0A444UKM60_RXVCR/1-127 Memid:7906\n']
# test2
# updating outputs ['QF7FO']
# memid 0 QF7FO 6596
# uniprotid: 0 ['>tr|UniRef100UPI001E1D8AEB0|UniRef100UPI001E1D8AEB0_QF7FO/1-127 Memid:6596\n']
# test2
# updating outputs ['GPF2V']
# memid 0 GPF2V 143995
# uniprotid: 0 ['>tr|UniRef100UPI000614D73A0|UniRef100UPI000614D73A0_GPF2V/1-127 Memid:143995\n']
# test2
# updating outputs ['SA3AF']
# memid 0 SA3AF 8469
# uniprotid: 0 ['>tr|UniRef100M7AYC50|UniRef100M7AYC50_SA3AF/1-127 Memid:8469\n']
# test2
# updating outputs ['CUNMR']
# memid 0 CUNMR 225164
# uniprotid: 0 ['>tr|UniRef100V4AFS60|UniRef100V4AFS60_CUNMR/1-127 Memid:225164\n']
# test2
# updating outputs ['TNBYT']
# memid 0 TNBYT 7668
# uniprotid: 0 ['>tr|UniRef100P168880|UniRef100P168880_TNBYT/1-127 Memid:7668\n']
# test2
# updating outputs ['XIAIX']
# memid 0 XIAIX 50429
# uniprotid: 0 ['>tr|UniRef100UPI000C03EC7F0|UniRef100UPI000C03EC7F0_XIAIX/1-127 Memid:50429\n']
# test2
# updating outputs ['WDU7E']
# memid 0 WDU7E 6105
# uniprotid: 0 ['>tr|UniRef100A0A6P8JBC80|UniRef100A0A6P8JBC80_WDU7E/1-127 Memid:6105\n']
# test2
# updating outputs ['YJ438']
# memid 0 YJ438 29053
# uniprotid: 0 ['>tr|UniRef100UPI0006C95E5D0|UniRef100UPI0006C95E5D0_YJ438/1-127 Memid:29053\n']
# test2
# updating outputs ['KMY0O']
# memid 0 KMY0O 41426
# uniprotid: 0 ['>tr|UniRef100UPI001FD919880|UniRef100UPI001FD919880_KMY0O/1-127 Memid:41426\n']
# test2
# updating outputs ['A04TT']
# memid 0 A04TT 6550
# uniprotid: 0 ['>tr|UniRef100A0A8S3SZY40|UniRef100A0A8S3SZY40_A04TT/1-127 Memid:6550\n']
# test2
# updating outputs ['ROIOU']
# memid 0 ROIOU 248454
# uniprotid: 0 ['>tr|UniRef100A0A8S9WPY60|UniRef100A0A8S9WPY60_ROIOU/1-127 Memid:248454\n']
# test2
# updating outputs ['JKBWZ']
# memid 0 JKBWZ 7245
# uniprotid: 0 ['>tr|UniRef100B4IW930|UniRef100B4IW930_JKBWZ/1-127 Memid:7245\n']
# test2
# updating outputs ['UP1YE']
# memid 0 UP1YE 6645
# uniprotid: 0 ['>tr|UniRef100A0A6P7S7310|UniRef100A0A6P7S7310_UP1YE/1-127 Memid:6645\n']
# test2
# updating outputs ['ER3DV']
# memid 0 ER3DV 241271
# uniprotid: 0 ['>tr|UniRef100UPI001BD2B0240|UniRef100UPI001BD2B0240_ER3DV/1-127 Memid:241271\n']
# test2
# updating outputs ['JUMPF']
# memid 0 JUMPF 10224
# uniprotid: 0 ['>tr|UniRef100UPI0003F0CF630|UniRef100UPI0003F0CF630_JUMPF/1-127 Memid:10224\n']
# test2
# updating outputs ['ES6DZ']
# memid 0 ES6DZ 7888
# uniprotid: 0 ['>tr|UniRef100UPI001CFBDA510|UniRef100UPI001CFBDA510_ES6DZ/1-127 Memid:7888\n']
# test2
# updating outputs ['UFJTV']
# memid 0 UFJTV 685728
# uniprotid: 0 ['>tr|UniRef100UPI00223E85690|UniRef100UPI00223E85690_UFJTV/1-127 Memid:685728\n']
# test2
# updating outputs ['I1TCD']
# memid 0 I1TCD 7200
# uniprotid: 0 ['>tr|UniRef100A0A1B0C9A60|UniRef100A0A1B0C9A60_I1TCD/1-127 Memid:7200\n']
# test2
# updating outputs ['EMHDN']
# memid 0 EMHDN 7739
# uniprotid: 0 ['>tr|UniRef100C3Z7730|UniRef100C3Z7730_EMHDN/1-127 Memid:7739\n']
# test2
# updating outputs ['ER3DV']
# memid 0 ER3DV 241271
# uniprotid: 0 ['>tr|UniRef100UPI001BD607B90|UniRef100UPI001BD607B90_ER3DV/1-127 Memid:241271\n']
# test2
# updating outputs ['B9NOJ']
# memid 0 B9NOJ 13658
# uniprotid: 0 ['>tr|UniRef100A0A915L2Y60|UniRef100A0A915L2Y60_B9NOJ/1-127 Memid:13658\n']
# test2
# updating outputs ['QLEWR']
# memid 0 QLEWR 61180
# uniprotid: 0 ['>tr|UniRef100A0A0B1SDA60|UniRef100A0A0B1SDA60_QLEWR/1-127 Memid:61180\n']
# test2
# updating outputs ['53LLR']
# memid 0 53LLR 61384
# uniprotid: 0 ['>tr|UniRef100UPI001F124D1F0|UniRef100UPI001F124D1F0_53LLR/1-127 Memid:61384\n']
# test2
# updating outputs ['SYDAF']
# memid 0 SYDAF 9770
# uniprotid: 0 ['>tr|UniRef100A0A643BRV80|UniRef100A0A643BRV80_SYDAF/1-127 Memid:9770\n']
# test2
# updating outputs ['3LIOD']
# memid 0 3LIOD 51028
# uniprotid: 0 ['>tr|UniRef100A0A0N4V6R60|UniRef100A0A0N4V6R60_3LIOD/1-127 Memid:51028\n']
# test2
# updating outputs ['QUN7D']
# memid 0 QUN7D 7159
# uniprotid: 0 ['>tr|UniRef100A0A6I8U5960|UniRef100A0A6I8U5960_QUN7D/1-127 Memid:7159\n']
# test2
# updating outputs ['LGAA2']
# memid 0 LGAA2 7830
# uniprotid: 0 ['>tr|UniRef100UPI0018F7B4980|UniRef100UPI0018F7B4980_LGAA2/1-127 Memid:7830\n']
# test2
# updating outputs ['XIAIX']
# memid 0 XIAIX 50429
# uniprotid: 0 ['>tr|UniRef100A0A2B4S7M40|UniRef100A0A2B4S7M40_XIAIX/1-127 Memid:50429\n']
# test2
# updating outputs ['WPRTJ']
# memid 0 WPRTJ 45351
# uniprotid: 0 ['>tr|UniRef100UPI0020776D360|UniRef100UPI0020776D360_WPRTJ/1-127 Memid:45351\n']
# test2
# updating outputs ['6RBPD']
# memid 0 6RBPD 1529436
# uniprotid: 0 ['>tr|UniRef100UPI00142575780|UniRef100UPI00142575780_6RBPD/1-127 Memid:1529436\n']
# test2
# updating outputs ['YJ438']
# memid 0 YJ438 29053
# uniprotid: 0 ['>tr|UniRef100UPI0006C985190|UniRef100UPI0006C985190_YJ438/1-127 Memid:29053\n']
# test2
# updating outputs ['GKZZV']
# memid 0 GKZZV 74940
# uniprotid: 0 ['>tr|UniRef100UPI000D0A32FB0|UniRef100UPI000D0A32FB0_GKZZV/1-127 Memid:74940\n']
# test2
# updating outputs ['73TQS']
# memid 0 73TQS 70543
# uniprotid: 0 ['>tr|UniRef100UPI0022228F630|UniRef100UPI0022228F630_73TQS/1-127 Memid:70543\n']
# test2
# updating outputs ['PDEXM']
# memid 0 PDEXM 48498
# uniprotid: 0 ['>tr|UniRef100UPI0009E41E5D0|UniRef100UPI0009E41E5D0_PDEXM/1-127 Memid:48498\n']
# test2
# updating outputs ['Y3CEP']
# memid 0 Y3CEP 8090
# uniprotid: 0 ['>tr|UniRef100A0A3P9LQ470|UniRef100A0A3P9LQ470_Y3CEP/1-127 Memid:8090\n']
# test2
# updating outputs ['FAIVJ']
# memid 0 FAIVJ 47308
# uniprotid: 0 ['>tr|UniRef100A0A8C6SZ280|UniRef100A0A8C6SZ280_FAIVJ/1-127 Memid:47308\n']
# test2
# updating outputs ['JQKQH']
# memid 0 JQKQH 70779
# uniprotid: 0 ['>tr|UniRef100UPI00077B00B00|UniRef100UPI00077B00B00_JQKQH/1-127 Memid:70779\n']
# test2
# updating outputs ['NQHRZ']
# memid 0 NQHRZ 6252
# uniprotid: 0 ['>tr|UniRef100A0A0M3I7410|UniRef100A0A0M3I7410_NQHRZ/1-127 Memid:6252\n']
# test2
# updating outputs ['6ZKEX']
# memid 0 6ZKEX 1561998
# ...
# memid 6 REEPF 9593
# uniprotid: 6 ['>tr|P044870|P044870_Z96JR/1-162 Memid:9505\n', '>tr|P044871|P044871_7GGM6/1-162 Memid:9368\n', '>tr|P044872|P044872_XP6BJ/1-162 Memid:9483\n', '>tr|P044873|P044873_A7SYW/1-162 Memid:57378\n', '>tr|P044874|P044874_SLMGY/1-162 Memid:34839\n', '>tr|P044875|P044875_8SLRO/1-162 Memid:499232\n', '>tr|P044876|P044876_REEPF/1-162 Memid:9593\n']
# memid 7 E4FJK 9606
# uniprotid: 7 ['>tr|P044870|P044870_Z96JR/1-162 Memid:9505\n', '>tr|P044871|P044871_7GGM6/1-162 Memid:9368\n', '>tr|P044872|P044872_XP6BJ/1-162 Memid:9483\n', '>tr|P044873|P044873_A7SYW/1-162 Memid:57378\n', '>tr|P044874|P044874_SLMGY/1-162 Memid:34839\n', '>tr|P044875|P044875_8SLRO/1-162 Memid:499232\n', '>tr|P044876|P044876_REEPF/1-162 Memid:9593\n', '>tr|P044877|P044877_E4FJK/1-162 Memid:9606\n']
# memid 8 DNU05 9580
# uniprotid: 8 ['>tr|P044870|P044870_Z96JR/1-162 Memid:9505\n', '>tr|P044871|P044871_7GGM6/1-162 Memid:9368\n', '>tr|P044872|P044872_XP6BJ/1-162 Memid:9483\n', '>tr|P044873|P044873_A7SYW/1-162 Memid:57378\n', '>tr|P044874|P044874_SLMGY/1-162 Memid:34839\n', '>tr|P044875|P044875_8SLRO/1-162 Memid:499232\n', '>tr|P044876|P044876_REEPF/1-162 Memid:9593\n', '>tr|P044877|P044877_E4FJK/1-162 Memid:9606\n', '>tr|P044878|P044878_DNU05/1-162 Memid:9580\n']
# memid 9 N1UGK 9986
# uniprotid: 9 ['>tr|P044870|P044870_Z96JR/1-162 Memid:9505\n', '>tr|P044871|P044871_7GGM6/1-162 Memid:9368\n', '>tr|P044872|P044872_XP6BJ/1-162 Memid:9483\n', '>tr|P044873|P044873_A7SYW/1-162 Memid:57378\n', '>tr|P044874|P044874_SLMGY/1-162 Memid:34839\n', '>tr|P044875|P044875_8SLRO/1-162 Memid:499232\n', '>tr|P044876|P044876_REEPF/1-162 Memid:9593\n', '>tr|P044877|P044877_E4FJK/1-162 Memid:9606\n', '>tr|P044878|P044878_DNU05/1-162 Memid:9580\n', '>tr|P044879|P044879_N1UGK/1-162 Memid:9986\n']
# memid 10 5R9PL 591935
# uniprotid: 10 ['>tr|P044870|P044870_Z96JR/1-162 Memid:9505\n', '>tr|P044871|P044871_7GGM6/1-162 Memid:9368\n', '>tr|P044872|P044872_XP6BJ/1-162 Memid:9483\n', '>tr|P044873|P044873_A7SYW/1-162 Memid:57378\n', '>tr|P044874|P044874_SLMGY/1-162 Memid:34839\n', '>tr|P044875|P044875_8SLRO/1-162 Memid:499232\n', '>tr|P044876|P044876_REEPF/1-162 Memid:9593\n', '>tr|P044877|P044877_E4FJK/1-162 Memid:9606\n', '>tr|P044878|P044878_DNU05/1-162 Memid:9580\n', '>tr|P044879|P044879_N1UGK/1-162 Memid:9986\n', '>tr|P0448710|P0448710_5R9PL/1-162 Memid:591935\n']
# memid 11 LHXW8 43777
# uniprotid: 11 ['>tr|P044870|P044870_Z96JR/1-162 Memid:9505\n', '>tr|P044871|P044871_7GGM6/1-162 Memid:9368\n', '>tr|P044872|P044872_XP6BJ/1-162 Memid:9483\n', '>tr|P044873|P044873_A7SYW/1-162 Memid:57378\n', '>tr|P044874|P044874_SLMGY/1-162 Memid:34839\n', '>tr|P044875|P044875_8SLRO/1-162 Memid:499232\n', '>tr|P044876|P044876_REEPF/1-162 Memid:9593\n', '>tr|P044877|P044877_E4FJK/1-162 Memid:9606\n', '>tr|P044878|P044878_DNU05/1-162 Memid:9580\n', '>tr|P044879|P044879_N1UGK/1-162 Memid:9986\n', '>tr|P0448710|P0448710_5R9PL/1-162 Memid:591935\n', '>tr|P0448711|P0448711_LHXW8/1-162 Memid:43777\n']
# memid 12 UA604 9739
# uniprotid: 12 ['>tr|P044870|P044870_Z96JR/1-162 Memid:9505\n', '>tr|P044871|P044871_7GGM6/1-162 Memid:9368\n', '>tr|P044872|P044872_XP6BJ/1-162 Memid:9483\n', '>tr|P044873|P044873_A7SYW/1-162 Memid:57378\n', '>tr|P044874|P044874_SLMGY/1-162 Memid:34839\n', '>tr|P044875|P044875_8SLRO/1-162 Memid:499232\n', '>tr|P044876|P044876_REEPF/1-162 Memid:9593\n', '>tr|P044877|P044877_E4FJK/1-162 Memid:9606\n', '>tr|P044878|P044878_DNU05/1-162 Memid:9580\n', '>tr|P044879|P044879_N1UGK/1-162 Memid:9986\n', '>tr|P0448710|P0448710_5R9PL/1-162 Memid:591935\n', '>tr|P0448711|P0448711_LHXW8/1-162 Memid:43777\n', '>tr|P0448712|P0448712_UA604/1-162 Memid:9739\n']
# updating outputs ['Z96JR', '7GGM6', 'XP6BJ', 'A7SYW', 'SLMGY', '8SLRO', 'REEPF', 'E4FJK', 'DNU05', 'N1UGK', '5R9PL', 'LHXW8', 'UA604']
# memid 0 Z96JR 9505
# uniprotid: 0 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n']
# memid 1 7GGM6 9368
# uniprotid: 1 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n']
# memid 2 XP6BJ 9483
# uniprotid: 2 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n']
# memid 3 A7SYW 57378
# uniprotid: 3 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n']
# memid 4 SLMGY 34839
# uniprotid: 4 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7CYE94|A0A0F7CYE94_SLMGY/1-162 Memid:34839\n']
# memid 5 8SLRO 499232
# uniprotid: 5 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7CYE94|A0A0F7CYE94_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7CYE95|A0A0F7CYE95_8SLRO/1-162 Memid:499232\n']
# memid 6 REEPF 9593
# uniprotid: 6 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7CYE94|A0A0F7CYE94_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7CYE95|A0A0F7CYE95_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7CYE96|A0A0F7CYE96_REEPF/1-162 Memid:9593\n']
# memid 7 E4FJK 9606
# uniprotid: 7 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7CYE94|A0A0F7CYE94_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7CYE95|A0A0F7CYE95_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7CYE96|A0A0F7CYE96_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7CYE97|A0A0F7CYE97_E4FJK/1-162 Memid:9606\n']
# memid 8 DNU05 9580
# uniprotid: 8 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7CYE94|A0A0F7CYE94_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7CYE95|A0A0F7CYE95_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7CYE96|A0A0F7CYE96_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7CYE97|A0A0F7CYE97_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7CYE98|A0A0F7CYE98_DNU05/1-162 Memid:9580\n']
# memid 9 N1UGK 9986
# uniprotid: 9 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7CYE94|A0A0F7CYE94_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7CYE95|A0A0F7CYE95_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7CYE96|A0A0F7CYE96_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7CYE97|A0A0F7CYE97_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7CYE98|A0A0F7CYE98_DNU05/1-162 Memid:9580\n', '>tr|A0A0F7CYE99|A0A0F7CYE99_N1UGK/1-162 Memid:9986\n']
# memid 10 5R9PL 591935
# uniprotid: 10 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7CYE94|A0A0F7CYE94_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7CYE95|A0A0F7CYE95_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7CYE96|A0A0F7CYE96_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7CYE97|A0A0F7CYE97_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7CYE98|A0A0F7CYE98_DNU05/1-162 Memid:9580\n', '>tr|A0A0F7CYE99|A0A0F7CYE99_N1UGK/1-162 Memid:9986\n', '>tr|A0A0F7CYE910|A0A0F7CYE910_5R9PL/1-162 Memid:591935\n']
# memid 11 LHXW8 43777
# uniprotid: 11 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7CYE94|A0A0F7CYE94_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7CYE95|A0A0F7CYE95_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7CYE96|A0A0F7CYE96_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7CYE97|A0A0F7CYE97_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7CYE98|A0A0F7CYE98_DNU05/1-162 Memid:9580\n', '>tr|A0A0F7CYE99|A0A0F7CYE99_N1UGK/1-162 Memid:9986\n', '>tr|A0A0F7CYE910|A0A0F7CYE910_5R9PL/1-162 Memid:591935\n', '>tr|A0A0F7CYE911|A0A0F7CYE911_LHXW8/1-162 Memid:43777\n']
# memid 12 UA604 9739
# uniprotid: 12 ['>tr|A0A0F7CYE90|A0A0F7CYE90_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7CYE91|A0A0F7CYE91_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7CYE92|A0A0F7CYE92_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7CYE93|A0A0F7CYE93_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7CYE94|A0A0F7CYE94_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7CYE95|A0A0F7CYE95_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7CYE96|A0A0F7CYE96_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7CYE97|A0A0F7CYE97_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7CYE98|A0A0F7CYE98_DNU05/1-162 Memid:9580\n', '>tr|A0A0F7CYE99|A0A0F7CYE99_N1UGK/1-162 Memid:9986\n', '>tr|A0A0F7CYE910|A0A0F7CYE910_5R9PL/1-162 Memid:591935\n', '>tr|A0A0F7CYE911|A0A0F7CYE911_LHXW8/1-162 Memid:43777\n', '>tr|A0A0F7CYE912|A0A0F7CYE912_UA604/1-162 Memid:9739\n']
# updating outputs ['Z96JR', '7GGM6', 'XP6BJ', 'A7SYW', 'SLMGY', '8SLRO', 'REEPF', 'E4FJK', 'DNU05', 'N1UGK', '5R9PL', 'LHXW8', 'UA604']
# memid 0 Z96JR 9505
# uniprotid: 0 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n']
# memid 1 7GGM6 9368
# uniprotid: 1 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n']
# memid 2 XP6BJ 9483
# uniprotid: 2 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n']
# memid 3 A7SYW 57378
# uniprotid: 3 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n']
# memid 4 SLMGY 34839
# uniprotid: 4 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7GTP24|A0A0F7GTP24_SLMGY/1-162 Memid:34839\n']
# memid 5 8SLRO 499232
# uniprotid: 5 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7GTP24|A0A0F7GTP24_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7GTP25|A0A0F7GTP25_8SLRO/1-162 Memid:499232\n']
# memid 6 REEPF 9593
# uniprotid: 6 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7GTP24|A0A0F7GTP24_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7GTP25|A0A0F7GTP25_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7GTP26|A0A0F7GTP26_REEPF/1-162 Memid:9593\n']
# memid 7 E4FJK 9606
# uniprotid: 7 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7GTP24|A0A0F7GTP24_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7GTP25|A0A0F7GTP25_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7GTP26|A0A0F7GTP26_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7GTP27|A0A0F7GTP27_E4FJK/1-162 Memid:9606\n']
# memid 8 DNU05 9580
# uniprotid: 8 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7GTP24|A0A0F7GTP24_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7GTP25|A0A0F7GTP25_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7GTP26|A0A0F7GTP26_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7GTP27|A0A0F7GTP27_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7GTP28|A0A0F7GTP28_DNU05/1-162 Memid:9580\n']
# memid 9 N1UGK 9986
# uniprotid: 9 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7GTP24|A0A0F7GTP24_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7GTP25|A0A0F7GTP25_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7GTP26|A0A0F7GTP26_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7GTP27|A0A0F7GTP27_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7GTP28|A0A0F7GTP28_DNU05/1-162 Memid:9580\n', '>tr|A0A0F7GTP29|A0A0F7GTP29_N1UGK/1-162 Memid:9986\n']
# memid 10 5R9PL 591935
# uniprotid: 10 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7GTP24|A0A0F7GTP24_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7GTP25|A0A0F7GTP25_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7GTP26|A0A0F7GTP26_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7GTP27|A0A0F7GTP27_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7GTP28|A0A0F7GTP28_DNU05/1-162 Memid:9580\n', '>tr|A0A0F7GTP29|A0A0F7GTP29_N1UGK/1-162 Memid:9986\n', '>tr|A0A0F7GTP210|A0A0F7GTP210_5R9PL/1-162 Memid:591935\n']
# memid 11 LHXW8 43777
# uniprotid: 11 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7GTP24|A0A0F7GTP24_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7GTP25|A0A0F7GTP25_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7GTP26|A0A0F7GTP26_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7GTP27|A0A0F7GTP27_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7GTP28|A0A0F7GTP28_DNU05/1-162 Memid:9580\n', '>tr|A0A0F7GTP29|A0A0F7GTP29_N1UGK/1-162 Memid:9986\n', '>tr|A0A0F7GTP210|A0A0F7GTP210_5R9PL/1-162 Memid:591935\n', '>tr|A0A0F7GTP211|A0A0F7GTP211_LHXW8/1-162 Memid:43777\n']
# memid 12 UA604 9739
# uniprotid: 12 ['>tr|A0A0F7GTP20|A0A0F7GTP20_Z96JR/1-162 Memid:9505\n', '>tr|A0A0F7GTP21|A0A0F7GTP21_7GGM6/1-162 Memid:9368\n', '>tr|A0A0F7GTP22|A0A0F7GTP22_XP6BJ/1-162 Memid:9483\n', '>tr|A0A0F7GTP23|A0A0F7GTP23_A7SYW/1-162 Memid:57378\n', '>tr|A0A0F7GTP24|A0A0F7GTP24_SLMGY/1-162 Memid:34839\n', '>tr|A0A0F7GTP25|A0A0F7GTP25_8SLRO/1-162 Memid:499232\n', '>tr|A0A0F7GTP26|A0A0F7GTP26_REEPF/1-162 Memid:9593\n', '>tr|A0A0F7GTP27|A0A0F7GTP27_E4FJK/1-162 Memid:9606\n', '>tr|A0A0F7GTP28|A0A0F7GTP28_DNU05/1-162 Memid:9580\n', '>tr|A0A0F7GTP29|A0A0F7GTP29_N1UGK/1-162 Memid:9986\n', '>tr|A0A0F7GTP210|A0A0F7GTP210_5R9PL/1-162 Memid:591935\n', '>tr|A0A0F7GTP211|A0A0F7GTP211_LHXW8/1-162 Memid:43777\n', '>tr|A0A0F7GTP212|A0A0F7GTP212_UA604/1-162 Memid:9739\n']
# updating outputs ['8SLRO', 'E4FJK', '4OFWS', '3PJA9']
# memid 0 8SLRO 499232
# uniprotid: 0 ['>tr|A0A110AVT90|A0A110AVT90_8SLRO/1-162 Memid:499232\n']
# memid 1 E4FJK 9606
# uniprotid: 1 ['>tr|A0A110AVT90|A0A110AVT90_8SLRO/1-162 Memid:499232\n', '>tr|A0A110AVT91|A0A110AVT91_E4FJK/1-162 Memid:9606\n']
# memid 2 4OFWS 9597
# uniprotid: 2 ['>tr|A0A110AVT90|A0A110AVT90_8SLRO/1-162 Memid:499232\n', '>tr|A0A110AVT91|A0A110AVT91_E4FJK/1-162 Memid:9606\n', '>tr|A0A110AVT92|A0A110AVT92_4OFWS/1-162 Memid:9597\n']
# memid 3 3PJA9 9598
# uniprotid: 3 ['>tr|A0A110AVT90|A0A110AVT90_8SLRO/1-162 Memid:499232\n', '>tr|A0A110AVT91|A0A110AVT91_E4FJK/1-162 Memid:9606\n', '>tr|A0A110AVT92|A0A110AVT92_4OFWS/1-162 Memid:9597\n', '>tr|A0A110AVT93|A0A110AVT93_3PJA9/1-162 Memid:9598\n']
